# %%
import datetime
import os
import random
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.io import loadmat
from scipy import signal
from scipy.signal import medfilt
import pywt
from pywt import wavedec

# %%
DATASET_DIR = 'data\WFDBRecords'
print('DATASET DIR ::',DATASET_DIR)
# Out:
# DATASET DIR :: data\WFDBRecords

# %%
g_DATA = '.mat'
g_HEAD = '.hea'
g_leads = ['I','II','III','aVR','aVL','aVF','V1','V2','V3','V4','V5','V6' ]
BASIC_SRATE = 500 #Hz
print('Basic sampling rate(Hz):',BASIC_SRATE)
# Out:
# Basic sampling rate(Hz): 500

# %%
for root, dirs, files in os.walk('.'):
    for filename in files:
        if filename == 'RECORDS':
            os.rename(os.path.join(root, filename), os.path.join(root, 'RECORDS.txt'))

# %%
rec_count = 0 
rec_count_expected = 0  # Initialize with 0, will be calculated below
rec_name_sep = ','
rec_file = open('RECORDS.txt', 'w')
# Traverse through all subfolders and files
for root, dirs, files in os.walk(DATASET_DIR):
    for f in files:
        if f.endswith(g_HEAD):
            rec_name = os.path.splitext(f)[0]  # Extract filename without extension
            rec_file.write(rec_name_sep + rec_name)
            rec_count += 1

    # Calculate the expected count by summing up the number of files with the desired extension
    rec_count_expected += len([f for f in files if f.endswith(g_HEAD)])

rec_file.seek(0)  # Move the file pointer to the beginning of the file
rec_file.write(str(rec_count_expected))  # Write the expected count to the beginning of the file
rec_file.close()

assert rec_count_expected == rec_count  # Assert the count equality
print(rec_count)
# Out:
# 45152

# %%
load_txt = np.loadtxt('./RECORDS.txt', delimiter=',', dtype='str')
rec_count = int(load_txt[0])
rec_list = load_txt[1:]
print(rec_count,len(rec_list))
# Out:
# 45152001 45151

# %%
def denoise_signal(X, dwt_transform, dlevels, cutoff_low, cutoff_high):
    coeffs = wavedec(X, dwt_transform, level=dlevels)   # wavelet transform 'bior4.4'
    # scale 0 to cutoff_low 
    for ca in range(0,cutoff_low):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    # scale cutoff_high to end
    for ca in range(cutoff_high, len(coeffs)):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    Y = pywt.waverec(coeffs, dwt_transform) # inverse wavelet transform
    return Y  

def get_median_filter_width(sampling_rate, duration):
    res = int( sampling_rate*duration )
    res += ((res%2) - 1) # needs to be an odd number
    return res
# baseline fitting by filtering
# === Define Filtering Params for Baseline fitting Leads======================
ms_flt_array = [0.2,0.6]    #<-- length of baseline fitting filters (in seconds)
mfa = np.zeros(len(ms_flt_array), dtype='int')
for i in range(0, len(ms_flt_array)):
    mfa[i] = get_median_filter_width(BASIC_SRATE,ms_flt_array[i])

def filter_signal(X):
    global mfa
    X0 = X  #read orignal signal
    for mi in range(0,len(mfa)):
        X0 = medfilt(X0,mfa[mi]) # apply median filter one by one on top of each other
    X0 = np.subtract(X,X0)  # finally subtract from orignal signal
    return X0

# %%
rec_count = 0 
rec_count_expected = 0  # Initialize with 0, will be calculated below
rec_name_sep = ','
rec_file = open('RECORDS.txt', 'w')
# Traverse through all subfolders and files
for root, dirs, files in os.walk(DATASET_DIR):
    for f in files:
        if f.endswith(g_HEAD):
            rec_name = os.path.splitext(f)[0]  # Extract filename without extension
            rec_file.write(rec_name_sep + rec_name)
            rec_count += 1

    # Calculate the expected count by summing up the number of files with the desired extension
    rec_count_expected += len([f for f in files if f.endswith(g_HEAD)])

rec_file.seek(0)  # Move the file pointer to the beginning of the file
rec_file.write(str(rec_count_expected))  # Write the expected count to the beginning of the file
rec_file.close()

assert rec_count_expected == rec_count  # Assert the count equality
print(rec_count)
# Out:
# 45152

# %%
import os
import scipy.io as sio

# Define the directory containing the original .mat files
INPUT_DIR = "data"

# Define the directory to save the modified .mat files
OUTPUT_DIR = "denoised_data"

# Define the list of ECG leads
g_leads = ['I','II','III','aVR','aVL','aVF','V1','V2','V3','V4','V5','V6']

# Create the output directory if it does not exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Gather all relevant records
rec_list = []
for root, dirs, files in os.walk(INPUT_DIR):
    for f in files:
        if f.endswith('.mat'):
            seg_name = os.path.splitext(f)[0]
            rec_list.append((seg_name, root))

# Select each record, modify its contents, and save it
for rec_name, rec_dir in rec_list:
    # Load the original .mat file
    file_path = os.path.join(rec_dir, f"{rec_name}.mat")
    try:
        original_data = sio.loadmat(file_path)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue
    
    # Modify the values of each lead's signal data
    for i in range(0, 12):
        _key = g_leads[i]
        original_data['val'][i, :] = filter_signal(denoise_signal(original_data['val'][i, :], 'bior4.4', 9, 1, 7))
    
    # Define the file name and path for the modified file
    modified_file_path = os.path.join(OUTPUT_DIR, f"{rec_name}.mat")
    
    # Save the modified data to a new .mat file
    sio.savemat(modified_file_path, original_data)
    
    print(f"Modified data for record '{rec_name}' saved to '{modified_file_path}'")
# Out:
# Modified data for record 'JS00001' saved to 'denoised_data\JS00001.mat'
# Modified data for record 'JS00002' saved to 'denoised_data\JS00002.mat'
# Modified data for record 'JS00004' saved to 'denoised_data\JS00004.mat'
# Modified data for record 'JS00005' saved to 'denoised_data\JS00005.mat'
# Modified data for record 'JS00006' saved to 'denoised_data\JS00006.mat'
# Modified data for record 'JS00007' saved to 'denoised_data\JS00007.mat'
# Modified data for record 'JS00008' saved to 'denoised_data\JS00008.mat'
# Modified data for record 'JS00009' saved to 'denoised_data\JS00009.mat'
# Modified data for record 'JS00010' saved to 'denoised_data\JS00010.mat'
# Modified data for record 'JS00011' saved to 'denoised_data\JS00011.mat'
# Modified data for record 'JS00012' saved to 'denoised_data\JS00012.mat'
# Modified data for record 'JS00013' saved to 'denoised_data\JS00013.mat'
# Modified data for record 'JS00014' saved to 'denoised_data\JS00014.mat'
# Modified data for record 'JS00015' saved to 'denoised_data\JS00015.mat'
# Modified data for record 'JS00016' saved to 'denoised_data\JS00016.mat'
# Modified data for record 'JS00017' saved to 'denoised_data\JS00017.mat'
# Modified data for record 'JS00018' saved to 'denoised_data\JS00018.mat'
# Modified data for record 'JS00019' saved to 'denoised_data\JS00019.mat'
# Modified data for record 'JS00020' saved to 'denoised_data\JS00020.mat'
# Modified data for record 'JS00021' saved to 'denoised_data\JS00021.mat'
# Modified data for record 'JS00022' saved to 'denoised_data\JS00022.mat'
# Modified data for record 'JS00023' saved to 'denoised_data\JS00023.mat'
# Modified data for record 'JS00024' saved to 'denoised_data\JS00024.mat'
# Modified data for record 'JS00025' saved to 'denoised_data\JS00025.mat'
# Modified data for record 'JS00026' saved to 'denoised_data\JS00026.mat'
# Modified data for record 'JS00027' saved to 'denoised_data\JS00027.mat'
# Modified data for record 'JS00029' saved to 'denoised_data\JS00029.mat'
# Modified data for record 'JS00030' saved to 'denoised_data\JS00030.mat'
# Modified data for record 'JS00031' saved to 'denoised_data\JS00031.mat'
# Modified data for record 'JS00032' saved to 'denoised_data\JS00032.mat'
# Modified data for record 'JS00033' saved to 'denoised_data\JS00033.mat'
# Modified data for record 'JS00034' saved to 'denoised_data\JS00034.mat'
# Modified data for record 'JS00036' saved to 'denoised_data\JS00036.mat'
# Modified data for record 'JS00037' saved to 'denoised_data\JS00037.mat'
# Modified data for record 'JS00038' saved to 'denoised_data\JS00038.mat'
# Modified data for record 'JS00039' saved to 'denoised_data\JS00039.mat'
# Modified data for record 'JS00040' saved to 'denoised_data\JS00040.mat'
# Modified data for record 'JS00041' saved to 'denoised_data\JS00041.mat'
# Modified data for record 'JS00042' saved to 'denoised_data\JS00042.mat'
# Modified data for record 'JS00043' saved to 'denoised_data\JS00043.mat'
# Modified data for record 'JS00044' saved to 'denoised_data\JS00044.mat'
# Modified data for record 'JS00045' saved to 'denoised_data\JS00045.mat'
# Modified data for record 'JS00046' saved to 'denoised_data\JS00046.mat'
# Modified data for record 'JS00047' saved to 'denoised_data\JS00047.mat'
# Modified data for record 'JS00048' saved to 'denoised_data\JS00048.mat'
# Modified data for record 'JS00049' saved to 'denoised_data\JS00049.mat'
# Modified data for record 'JS00050' saved to 'denoised_data\JS00050.mat'
# Modified data for record 'JS00051' saved to 'denoised_data\JS00051.mat'
# Modified data for record 'JS00052' saved to 'denoised_data\JS00052.mat'
# Modified data for record 'JS00053' saved to 'denoised_data\JS00053.mat'
# Modified data for record 'JS00054' saved to 'denoised_data\JS00054.mat'
# Modified data for record 'JS00055' saved to 'denoised_data\JS00055.mat'
# Modified data for record 'JS00056' saved to 'denoised_data\JS00056.mat'
# Modified data for record 'JS00057' saved to 'denoised_data\JS00057.mat'
# Modified data for record 'JS00058' saved to 'denoised_data\JS00058.mat'
# Modified data for record 'JS00059' saved to 'denoised_data\JS00059.mat'
# Modified data for record 'JS00060' saved to 'denoised_data\JS00060.mat'
# Modified data for record 'JS00061' saved to 'denoised_data\JS00061.mat'
# Modified data for record 'JS00062' saved to 'denoised_data\JS00062.mat'
# Modified data for record 'JS00063' saved to 'denoised_data\JS00063.mat'
# Modified data for record 'JS00064' saved to 'denoised_data\JS00064.mat'
# Modified data for record 'JS00065' saved to 'denoised_data\JS00065.mat'
# Modified data for record 'JS00066' saved to 'denoised_data\JS00066.mat'
# Modified data for record 'JS00067' saved to 'denoised_data\JS00067.mat'
# Modified data for record 'JS00068' saved to 'denoised_data\JS00068.mat'
# Modified data for record 'JS00069' saved to 'denoised_data\JS00069.mat'
# Modified data for record 'JS00070' saved to 'denoised_data\JS00070.mat'
# Modified data for record 'JS00071' saved to 'denoised_data\JS00071.mat'
# Modified data for record 'JS00072' saved to 'denoised_data\JS00072.mat'
# Modified data for record 'JS00073' saved to 'denoised_data\JS00073.mat'
# Modified data for record 'JS00074' saved to 'denoised_data\JS00074.mat'
# Modified data for record 'JS00075' saved to 'denoised_data\JS00075.mat'
# Modified data for record 'JS00076' saved to 'denoised_data\JS00076.mat'
# Modified data for record 'JS00077' saved to 'denoised_data\JS00077.mat'
# Modified data for record 'JS00078' saved to 'denoised_data\JS00078.mat'
# Modified data for record 'JS00079' saved to 'denoised_data\JS00079.mat'
# Modified data for record 'JS00080' saved to 'denoised_data\JS00080.mat'
# Modified data for record 'JS00081' saved to 'denoised_data\JS00081.mat'
# Modified data for record 'JS00082' saved to 'denoised_data\JS00082.mat'
# Modified data for record 'JS00083' saved to 'denoised_data\JS00083.mat'
# Modified data for record 'JS00084' saved to 'denoised_data\JS00084.mat'
# Modified data for record 'JS00085' saved to 'denoised_data\JS00085.mat'
# Modified data for record 'JS00086' saved to 'denoised_data\JS00086.mat'
# Modified data for record 'JS00087' saved to 'denoised_data\JS00087.mat'
# Modified data for record 'JS00088' saved to 'denoised_data\JS00088.mat'
# Modified data for record 'JS00089' saved to 'denoised_data\JS00089.mat'
# Modified data for record 'JS00090' saved to 'denoised_data\JS00090.mat'
# Modified data for record 'JS00091' saved to 'denoised_data\JS00091.mat'
# Modified data for record 'JS00092' saved to 'denoised_data\JS00092.mat'
# Modified data for record 'JS00093' saved to 'denoised_data\JS00093.mat'
# Modified data for record 'JS00094' saved to 'denoised_data\JS00094.mat'
# Modified data for record 'JS00095' saved to 'denoised_data\JS00095.mat'
# Modified data for record 'JS00096' saved to 'denoised_data\JS00096.mat'
# Modified data for record 'JS00097' saved to 'denoised_data\JS00097.mat'
# Modified data for record 'JS00099' saved to 'denoised_data\JS00099.mat'
# Modified data for record 'JS00100' saved to 'denoised_data\JS00100.mat'
# Modified data for record 'JS00101' saved to 'denoised_data\JS00101.mat'
# Modified data for record 'JS00102' saved to 'denoised_data\JS00102.mat'
# Modified data for record 'JS00103' saved to 'denoised_data\JS00103.mat'
# Modified data for record 'JS00104' saved to 'denoised_data\JS00104.mat'
# Modified data for record 'JS00105' saved to 'denoised_data\JS00105.mat'
# Modified data for record 'JS00106' saved to 'denoised_data\JS00106.mat'
# Modified data for record 'JS00107' saved to 'denoised_data\JS00107.mat'
# Modified data for record 'JS00108' saved to 'denoised_data\JS00108.mat'
# Modified data for record 'JS00109' saved to 'denoised_data\JS00109.mat'
# Modified data for record 'JS00110' saved to 'denoised_data\JS00110.mat'
# Modified data for record 'JS00111' saved to 'denoised_data\JS00111.mat'
# Modified data for record 'JS00112' saved to 'denoised_data\JS00112.mat'
# Modified data for record 'JS00113' saved to 'denoised_data\JS00113.mat'
# Modified data for record 'JS00114' saved to 'denoised_data\JS00114.mat'
# Modified data for record 'JS00115' saved to 'denoised_data\JS00115.mat'
# Modified data for record 'JS00116' saved to 'denoised_data\JS00116.mat'
# Modified data for record 'JS00117' saved to 'denoised_data\JS00117.mat'
# Modified data for record 'JS00118' saved to 'denoised_data\JS00118.mat'
# Modified data for record 'JS00119' saved to 'denoised_data\JS00119.mat'
# Modified data for record 'JS00120' saved to 'denoised_data\JS00120.mat'
# Modified data for record 'JS00121' saved to 'denoised_data\JS00121.mat'
# Modified data for record 'JS00122' saved to 'denoised_data\JS00122.mat'
# Modified data for record 'JS00123' saved to 'denoised_data\JS00123.mat'
# Modified data for record 'JS00124' saved to 'denoised_data\JS00124.mat'
# Modified data for record 'JS00125' saved to 'denoised_data\JS00125.mat'
# Modified data for record 'JS00126' saved to 'denoised_data\JS00126.mat'
# Modified data for record 'JS00127' saved to 'denoised_data\JS00127.mat'
# Modified data for record 'JS00128' saved to 'denoised_data\JS00128.mat'
# Modified data for record 'JS00129' saved to 'denoised_data\JS00129.mat'
# Modified data for record 'JS00130' saved to 'denoised_data\JS00130.mat'
# Modified data for record 'JS00131' saved to 'denoised_data\JS00131.mat'
# Modified data for record 'JS00132' saved to 'denoised_data\JS00132.mat'
# Modified data for record 'JS00133' saved to 'denoised_data\JS00133.mat'
# Modified data for record 'JS00134' saved to 'denoised_data\JS00134.mat'
# Modified data for record 'JS00137' saved to 'denoised_data\JS00137.mat'
# Modified data for record 'JS00138' saved to 'denoised_data\JS00138.mat'
# Modified data for record 'JS00139' saved to 'denoised_data\JS00139.mat'
# Modified data for record 'JS00140' saved to 'denoised_data\JS00140.mat'
# Modified data for record 'JS00141' saved to 'denoised_data\JS00141.mat'
# Modified data for record 'JS00142' saved to 'denoised_data\JS00142.mat'
# Modified data for record 'JS00143' saved to 'denoised_data\JS00143.mat'
# Modified data for record 'JS00144' saved to 'denoised_data\JS00144.mat'
# Modified data for record 'JS00145' saved to 'denoised_data\JS00145.mat'
# Modified data for record 'JS00146' saved to 'denoised_data\JS00146.mat'
# Modified data for record 'JS00147' saved to 'denoised_data\JS00147.mat'
# Modified data for record 'JS00148' saved to 'denoised_data\JS00148.mat'
# Modified data for record 'JS00150' saved to 'denoised_data\JS00150.mat'
# Modified data for record 'JS00151' saved to 'denoised_data\JS00151.mat'
# Modified data for record 'JS00152' saved to 'denoised_data\JS00152.mat'
# Modified data for record 'JS00153' saved to 'denoised_data\JS00153.mat'
# Modified data for record 'JS00154' saved to 'denoised_data\JS00154.mat'
# Modified data for record 'JS00155' saved to 'denoised_data\JS00155.mat'
# Modified data for record 'JS00156' saved to 'denoised_data\JS00156.mat'
# Modified data for record 'JS00157' saved to 'denoised_data\JS00157.mat'
# Modified data for record 'JS00158' saved to 'denoised_data\JS00158.mat'
# Modified data for record 'JS00159' saved to 'denoised_data\JS00159.mat'
# Modified data for record 'JS00160' saved to 'denoised_data\JS00160.mat'
# Modified data for record 'JS00161' saved to 'denoised_data\JS00161.mat'
# Modified data for record 'JS00162' saved to 'denoised_data\JS00162.mat'
# Modified data for record 'JS00163' saved to 'denoised_data\JS00163.mat'
# Modified data for record 'JS00164' saved to 'denoised_data\JS00164.mat'
# Modified data for record 'JS00165' saved to 'denoised_data\JS00165.mat'
# Modified data for record 'JS00166' saved to 'denoised_data\JS00166.mat'
# Modified data for record 'JS00167' saved to 'denoised_data\JS00167.mat'
# Modified data for record 'JS00168' saved to 'denoised_data\JS00168.mat'
# Modified data for record 'JS00169' saved to 'denoised_data\JS00169.mat'
# Modified data for record 'JS00170' saved to 'denoised_data\JS00170.mat'
# Modified data for record 'JS00171' saved to 'denoised_data\JS00171.mat'
# Modified data for record 'JS00172' saved to 'denoised_data\JS00172.mat'
# Modified data for record 'JS00173' saved to 'denoised_data\JS00173.mat'
# Modified data for record 'JS00174' saved to 'denoised_data\JS00174.mat'
# Modified data for record 'JS00175' saved to 'denoised_data\JS00175.mat'
# Modified data for record 'JS00176' saved to 'denoised_data\JS00176.mat'
# Modified data for record 'JS00177' saved to 'denoised_data\JS00177.mat'
# Modified data for record 'JS00178' saved to 'denoised_data\JS00178.mat'
# Modified data for record 'JS00179' saved to 'denoised_data\JS00179.mat'
# Modified data for record 'JS00180' saved to 'denoised_data\JS00180.mat'
# Modified data for record 'JS00181' saved to 'denoised_data\JS00181.mat'
# Modified data for record 'JS00182' saved to 'denoised_data\JS00182.mat'
# Modified data for record 'JS00183' saved to 'denoised_data\JS00183.mat'
# Modified data for record 'JS00184' saved to 'denoised_data\JS00184.mat'
# Modified data for record 'JS00185' saved to 'denoised_data\JS00185.mat'
# Modified data for record 'JS00186' saved to 'denoised_data\JS00186.mat'
# Modified data for record 'JS00187' saved to 'denoised_data\JS00187.mat'
# Modified data for record 'JS00188' saved to 'denoised_data\JS00188.mat'
# Modified data for record 'JS00189' saved to 'denoised_data\JS00189.mat'
# Modified data for record 'JS00190' saved to 'denoised_data\JS00190.mat'
# Modified data for record 'JS00191' saved to 'denoised_data\JS00191.mat'
# Modified data for record 'JS00192' saved to 'denoised_data\JS00192.mat'
# Modified data for record 'JS00193' saved to 'denoised_data\JS00193.mat'
# Modified data for record 'JS00194' saved to 'denoised_data\JS00194.mat'
# Modified data for record 'JS00195' saved to 'denoised_data\JS00195.mat'
# Modified data for record 'JS00196' saved to 'denoised_data\JS00196.mat'
# Modified data for record 'JS00197' saved to 'denoised_data\JS00197.mat'
# Modified data for record 'JS00198' saved to 'denoised_data\JS00198.mat'
# Modified data for record 'JS00199' saved to 'denoised_data\JS00199.mat'
# Modified data for record 'JS00200' saved to 'denoised_data\JS00200.mat'
# Modified data for record 'JS00201' saved to 'denoised_data\JS00201.mat'
# Modified data for record 'JS00202' saved to 'denoised_data\JS00202.mat'
# Modified data for record 'JS00203' saved to 'denoised_data\JS00203.mat'
# Modified data for record 'JS00204' saved to 'denoised_data\JS00204.mat'
# Modified data for record 'JS00205' saved to 'denoised_data\JS00205.mat'
# Modified data for record 'JS00206' saved to 'denoised_data\JS00206.mat'
# Modified data for record 'JS00207' saved to 'denoised_data\JS00207.mat'
# Modified data for record 'JS00208' saved to 'denoised_data\JS00208.mat'
# Modified data for record 'JS00209' saved to 'denoised_data\JS00209.mat'
# Modified data for record 'JS00210' saved to 'denoised_data\JS00210.mat'
# Modified data for record 'JS00211' saved to 'denoised_data\JS00211.mat'
# Modified data for record 'JS00212' saved to 'denoised_data\JS00212.mat'
# Modified data for record 'JS00213' saved to 'denoised_data\JS00213.mat'
# Modified data for record 'JS00215' saved to 'denoised_data\JS00215.mat'
# Modified data for record 'JS00216' saved to 'denoised_data\JS00216.mat'
# Modified data for record 'JS00217' saved to 'denoised_data\JS00217.mat'
# Modified data for record 'JS00218' saved to 'denoised_data\JS00218.mat'
# Modified data for record 'JS00219' saved to 'denoised_data\JS00219.mat'
# Modified data for record 'JS00220' saved to 'denoised_data\JS00220.mat'
# Modified data for record 'JS00221' saved to 'denoised_data\JS00221.mat'
# Modified data for record 'JS00222' saved to 'denoised_data\JS00222.mat'
# Modified data for record 'JS00223' saved to 'denoised_data\JS00223.mat'
# Modified data for record 'JS00224' saved to 'denoised_data\JS00224.mat'
# Modified data for record 'JS00225' saved to 'denoised_data\JS00225.mat'
# Modified data for record 'JS00226' saved to 'denoised_data\JS00226.mat'
# Modified data for record 'JS00227' saved to 'denoised_data\JS00227.mat'
# Modified data for record 'JS00228' saved to 'denoised_data\JS00228.mat'
# Modified data for record 'JS00229' saved to 'denoised_data\JS00229.mat'
# Modified data for record 'JS00230' saved to 'denoised_data\JS00230.mat'
# Modified data for record 'JS00231' saved to 'denoised_data\JS00231.mat'
# Modified data for record 'JS00232' saved to 'denoised_data\JS00232.mat'
# Modified data for record 'JS00233' saved to 'denoised_data\JS00233.mat'
# Modified data for record 'JS00234' saved to 'denoised_data\JS00234.mat'
# Modified data for record 'JS00235' saved to 'denoised_data\JS00235.mat'
# Modified data for record 'JS00236' saved to 'denoised_data\JS00236.mat'
# Modified data for record 'JS00237' saved to 'denoised_data\JS00237.mat'
# Modified data for record 'JS00238' saved to 'denoised_data\JS00238.mat'
# Modified data for record 'JS00239' saved to 'denoised_data\JS00239.mat'
# Modified data for record 'JS00240' saved to 'denoised_data\JS00240.mat'
# Modified data for record 'JS00241' saved to 'denoised_data\JS00241.mat'
# Modified data for record 'JS00242' saved to 'denoised_data\JS00242.mat'
# Modified data for record 'JS00243' saved to 'denoised_data\JS00243.mat'
# Modified data for record 'JS00244' saved to 'denoised_data\JS00244.mat'
# Modified data for record 'JS00245' saved to 'denoised_data\JS00245.mat'
# Modified data for record 'JS00247' saved to 'denoised_data\JS00247.mat'
# Modified data for record 'JS00248' saved to 'denoised_data\JS00248.mat'
# Modified data for record 'JS00249' saved to 'denoised_data\JS00249.mat'
# Modified data for record 'JS00250' saved to 'denoised_data\JS00250.mat'
# Modified data for record 'JS00251' saved to 'denoised_data\JS00251.mat'
# Modified data for record 'JS00252' saved to 'denoised_data\JS00252.mat'
# Modified data for record 'JS00253' saved to 'denoised_data\JS00253.mat'
# Modified data for record 'JS00254' saved to 'denoised_data\JS00254.mat'
# Modified data for record 'JS00255' saved to 'denoised_data\JS00255.mat'
# Modified data for record 'JS00256' saved to 'denoised_data\JS00256.mat'
# Modified data for record 'JS00257' saved to 'denoised_data\JS00257.mat'
# Modified data for record 'JS00258' saved to 'denoised_data\JS00258.mat'
# Modified data for record 'JS00259' saved to 'denoised_data\JS00259.mat'
# Modified data for record 'JS00260' saved to 'denoised_data\JS00260.mat'
# Modified data for record 'JS00261' saved to 'denoised_data\JS00261.mat'
# Modified data for record 'JS00262' saved to 'denoised_data\JS00262.mat'
# Modified data for record 'JS00263' saved to 'denoised_data\JS00263.mat'
# Modified data for record 'JS00264' saved to 'denoised_data\JS00264.mat'
# Modified data for record 'JS00265' saved to 'denoised_data\JS00265.mat'
# Modified data for record 'JS00266' saved to 'denoised_data\JS00266.mat'
# Modified data for record 'JS00267' saved to 'denoised_data\JS00267.mat'
# Modified data for record 'JS00268' saved to 'denoised_data\JS00268.mat'
# Modified data for record 'JS00269' saved to 'denoised_data\JS00269.mat'
# Modified data for record 'JS00270' saved to 'denoised_data\JS00270.mat'
# Modified data for record 'JS00271' saved to 'denoised_data\JS00271.mat'
# Modified data for record 'JS00272' saved to 'denoised_data\JS00272.mat'
# Modified data for record 'JS00273' saved to 'denoised_data\JS00273.mat'
# Modified data for record 'JS00274' saved to 'denoised_data\JS00274.mat'
# Modified data for record 'JS00276' saved to 'denoised_data\JS00276.mat'
# Modified data for record 'JS00277' saved to 'denoised_data\JS00277.mat'
# Modified data for record 'JS00278' saved to 'denoised_data\JS00278.mat'
# Modified data for record 'JS00279' saved to 'denoised_data\JS00279.mat'
# Modified data for record 'JS00280' saved to 'denoised_data\JS00280.mat'
# Modified data for record 'JS00281' saved to 'denoised_data\JS00281.mat'
# Modified data for record 'JS00282' saved to 'denoised_data\JS00282.mat'
# Modified data for record 'JS00283' saved to 'denoised_data\JS00283.mat'
# Modified data for record 'JS00284' saved to 'denoised_data\JS00284.mat'
# Modified data for record 'JS00285' saved to 'denoised_data\JS00285.mat'
# Modified data for record 'JS00286' saved to 'denoised_data\JS00286.mat'
# Modified data for record 'JS00287' saved to 'denoised_data\JS00287.mat'
# Modified data for record 'JS00288' saved to 'denoised_data\JS00288.mat'
# Modified data for record 'JS00289' saved to 'denoised_data\JS00289.mat'
# Modified data for record 'JS00290' saved to 'denoised_data\JS00290.mat'
# Modified data for record 'JS00291' saved to 'denoised_data\JS00291.mat'
# Modified data for record 'JS00292' saved to 'denoised_data\JS00292.mat'
# Modified data for record 'JS00293' saved to 'denoised_data\JS00293.mat'
# Modified data for record 'JS00294' saved to 'denoised_data\JS00294.mat'
# Modified data for record 'JS00295' saved to 'denoised_data\JS00295.mat'
# Modified data for record 'JS00296' saved to 'denoised_data\JS00296.mat'
# Modified data for record 'JS00297' saved to 'denoised_data\JS00297.mat'
# Modified data for record 'JS00298' saved to 'denoised_data\JS00298.mat'
# Modified data for record 'JS00299' saved to 'denoised_data\JS00299.mat'
# Modified data for record 'JS00300' saved to 'denoised_data\JS00300.mat'
# Modified data for record 'JS00301' saved to 'denoised_data\JS00301.mat'
# Modified data for record 'JS00302' saved to 'denoised_data\JS00302.mat'
# Modified data for record 'JS00303' saved to 'denoised_data\JS00303.mat'
# Modified data for record 'JS00304' saved to 'denoised_data\JS00304.mat'
# Modified data for record 'JS00305' saved to 'denoised_data\JS00305.mat'
# Modified data for record 'JS00306' saved to 'denoised_data\JS00306.mat'
# Modified data for record 'JS00307' saved to 'denoised_data\JS00307.mat'
# Modified data for record 'JS00308' saved to 'denoised_data\JS00308.mat'
# Modified data for record 'JS00309' saved to 'denoised_data\JS00309.mat'
# Modified data for record 'JS00310' saved to 'denoised_data\JS00310.mat'
# Modified data for record 'JS00311' saved to 'denoised_data\JS00311.mat'
# Modified data for record 'JS00312' saved to 'denoised_data\JS00312.mat'
# Modified data for record 'JS00313' saved to 'denoised_data\JS00313.mat'
# Modified data for record 'JS00314' saved to 'denoised_data\JS00314.mat'
# Modified data for record 'JS00315' saved to 'denoised_data\JS00315.mat'
# Modified data for record 'JS00316' saved to 'denoised_data\JS00316.mat'
# Modified data for record 'JS00317' saved to 'denoised_data\JS00317.mat'
# Modified data for record 'JS00318' saved to 'denoised_data\JS00318.mat'
# Modified data for record 'JS00319' saved to 'denoised_data\JS00319.mat'
# Modified data for record 'JS00320' saved to 'denoised_data\JS00320.mat'
# Modified data for record 'JS00321' saved to 'denoised_data\JS00321.mat'
# Modified data for record 'JS00322' saved to 'denoised_data\JS00322.mat'
# Modified data for record 'JS00323' saved to 'denoised_data\JS00323.mat'
# Modified data for record 'JS00324' saved to 'denoised_data\JS00324.mat'
# Modified data for record 'JS00325' saved to 'denoised_data\JS00325.mat'
# Modified data for record 'JS00326' saved to 'denoised_data\JS00326.mat'
# Modified data for record 'JS00327' saved to 'denoised_data\JS00327.mat'
# Modified data for record 'JS00328' saved to 'denoised_data\JS00328.mat'
# Modified data for record 'JS00329' saved to 'denoised_data\JS00329.mat'
# Modified data for record 'JS00330' saved to 'denoised_data\JS00330.mat'
# Modified data for record 'JS00331' saved to 'denoised_data\JS00331.mat'
# Modified data for record 'JS00332' saved to 'denoised_data\JS00332.mat'
# Modified data for record 'JS00333' saved to 'denoised_data\JS00333.mat'
# Modified data for record 'JS00334' saved to 'denoised_data\JS00334.mat'
# Modified data for record 'JS00335' saved to 'denoised_data\JS00335.mat'
# Modified data for record 'JS00336' saved to 'denoised_data\JS00336.mat'
# Modified data for record 'JS00337' saved to 'denoised_data\JS00337.mat'
# Modified data for record 'JS00338' saved to 'denoised_data\JS00338.mat'
# Modified data for record 'JS00339' saved to 'denoised_data\JS00339.mat'
# Modified data for record 'JS00340' saved to 'denoised_data\JS00340.mat'
# Modified data for record 'JS00341' saved to 'denoised_data\JS00341.mat'
# Modified data for record 'JS00342' saved to 'denoised_data\JS00342.mat'
# Modified data for record 'JS00343' saved to 'denoised_data\JS00343.mat'
# Modified data for record 'JS00344' saved to 'denoised_data\JS00344.mat'
# Modified data for record 'JS00345' saved to 'denoised_data\JS00345.mat'
# Modified data for record 'JS00346' saved to 'denoised_data\JS00346.mat'
# Modified data for record 'JS00347' saved to 'denoised_data\JS00347.mat'
# Modified data for record 'JS00348' saved to 'denoised_data\JS00348.mat'
# Modified data for record 'JS00349' saved to 'denoised_data\JS00349.mat'
# Modified data for record 'JS00350' saved to 'denoised_data\JS00350.mat'
# Modified data for record 'JS00351' saved to 'denoised_data\JS00351.mat'
# Modified data for record 'JS00352' saved to 'denoised_data\JS00352.mat'
# Modified data for record 'JS00353' saved to 'denoised_data\JS00353.mat'
# Modified data for record 'JS00354' saved to 'denoised_data\JS00354.mat'
# Modified data for record 'JS00355' saved to 'denoised_data\JS00355.mat'
# Modified data for record 'JS00356' saved to 'denoised_data\JS00356.mat'
# Modified data for record 'JS00357' saved to 'denoised_data\JS00357.mat'
# Modified data for record 'JS00358' saved to 'denoised_data\JS00358.mat'
# Modified data for record 'JS00359' saved to 'denoised_data\JS00359.mat'
# Modified data for record 'JS00360' saved to 'denoised_data\JS00360.mat'
# Modified data for record 'JS00361' saved to 'denoised_data\JS00361.mat'
# Modified data for record 'JS00362' saved to 'denoised_data\JS00362.mat'
# Modified data for record 'JS00363' saved to 'denoised_data\JS00363.mat'
# Modified data for record 'JS00364' saved to 'denoised_data\JS00364.mat'
# Modified data for record 'JS00365' saved to 'denoised_data\JS00365.mat'
# Modified data for record 'JS00366' saved to 'denoised_data\JS00366.mat'
# Modified data for record 'JS00367' saved to 'denoised_data\JS00367.mat'
# Modified data for record 'JS00368' saved to 'denoised_data\JS00368.mat'
# Modified data for record 'JS00369' saved to 'denoised_data\JS00369.mat'
# Modified data for record 'JS00370' saved to 'denoised_data\JS00370.mat'
# Modified data for record 'JS00371' saved to 'denoised_data\JS00371.mat'
# Modified data for record 'JS00372' saved to 'denoised_data\JS00372.mat'
# Modified data for record 'JS00373' saved to 'denoised_data\JS00373.mat'
# Modified data for record 'JS00374' saved to 'denoised_data\JS00374.mat'
# Modified data for record 'JS00375' saved to 'denoised_data\JS00375.mat'
# Modified data for record 'JS00376' saved to 'denoised_data\JS00376.mat'
# Modified data for record 'JS00377' saved to 'denoised_data\JS00377.mat'
# Modified data for record 'JS00378' saved to 'denoised_data\JS00378.mat'
# Modified data for record 'JS00379' saved to 'denoised_data\JS00379.mat'
# Modified data for record 'JS00380' saved to 'denoised_data\JS00380.mat'
# Modified data for record 'JS00381' saved to 'denoised_data\JS00381.mat'
# Modified data for record 'JS00382' saved to 'denoised_data\JS00382.mat'
# Modified data for record 'JS00383' saved to 'denoised_data\JS00383.mat'
# Modified data for record 'JS00384' saved to 'denoised_data\JS00384.mat'
# Modified data for record 'JS00385' saved to 'denoised_data\JS00385.mat'
# Modified data for record 'JS00386' saved to 'denoised_data\JS00386.mat'
# Modified data for record 'JS00387' saved to 'denoised_data\JS00387.mat'
# Modified data for record 'JS00388' saved to 'denoised_data\JS00388.mat'
# Modified data for record 'JS00389' saved to 'denoised_data\JS00389.mat'
# Modified data for record 'JS00390' saved to 'denoised_data\JS00390.mat'
# Modified data for record 'JS00391' saved to 'denoised_data\JS00391.mat'
# Modified data for record 'JS00392' saved to 'denoised_data\JS00392.mat'
# Modified data for record 'JS00393' saved to 'denoised_data\JS00393.mat'
# Modified data for record 'JS00394' saved to 'denoised_data\JS00394.mat'
# Modified data for record 'JS00395' saved to 'denoised_data\JS00395.mat'
# Modified data for record 'JS00396' saved to 'denoised_data\JS00396.mat'
# Modified data for record 'JS00397' saved to 'denoised_data\JS00397.mat'
# Modified data for record 'JS00398' saved to 'denoised_data\JS00398.mat'
# Modified data for record 'JS00399' saved to 'denoised_data\JS00399.mat'
# Modified data for record 'JS00400' saved to 'denoised_data\JS00400.mat'
# Modified data for record 'JS00401' saved to 'denoised_data\JS00401.mat'
# Modified data for record 'JS00402' saved to 'denoised_data\JS00402.mat'
# Modified data for record 'JS00403' saved to 'denoised_data\JS00403.mat'
# Modified data for record 'JS00404' saved to 'denoised_data\JS00404.mat'
# Modified data for record 'JS00405' saved to 'denoised_data\JS00405.mat'
# Modified data for record 'JS00406' saved to 'denoised_data\JS00406.mat'
# Modified data for record 'JS00407' saved to 'denoised_data\JS00407.mat'
# Modified data for record 'JS00408' saved to 'denoised_data\JS00408.mat'
# Modified data for record 'JS00409' saved to 'denoised_data\JS00409.mat'
# Modified data for record 'JS00410' saved to 'denoised_data\JS00410.mat'
# Modified data for record 'JS00411' saved to 'denoised_data\JS00411.mat'
# Modified data for record 'JS00412' saved to 'denoised_data\JS00412.mat'
# Modified data for record 'JS00413' saved to 'denoised_data\JS00413.mat'
# Modified data for record 'JS00414' saved to 'denoised_data\JS00414.mat'
# Modified data for record 'JS00415' saved to 'denoised_data\JS00415.mat'
# Modified data for record 'JS00417' saved to 'denoised_data\JS00417.mat'
# Modified data for record 'JS00420' saved to 'denoised_data\JS00420.mat'
# Modified data for record 'JS00421' saved to 'denoised_data\JS00421.mat'
# Modified data for record 'JS00422' saved to 'denoised_data\JS00422.mat'
# Modified data for record 'JS00423' saved to 'denoised_data\JS00423.mat'
# Modified data for record 'JS00424' saved to 'denoised_data\JS00424.mat'
# Modified data for record 'JS00425' saved to 'denoised_data\JS00425.mat'
# Modified data for record 'JS00426' saved to 'denoised_data\JS00426.mat'
# Modified data for record 'JS00427' saved to 'denoised_data\JS00427.mat'
# Modified data for record 'JS00428' saved to 'denoised_data\JS00428.mat'
# Modified data for record 'JS00429' saved to 'denoised_data\JS00429.mat'
# Modified data for record 'JS00430' saved to 'denoised_data\JS00430.mat'
# Modified data for record 'JS00431' saved to 'denoised_data\JS00431.mat'
# Modified data for record 'JS00432' saved to 'denoised_data\JS00432.mat'
# Modified data for record 'JS00433' saved to 'denoised_data\JS00433.mat'
# Modified data for record 'JS00434' saved to 'denoised_data\JS00434.mat'
# Modified data for record 'JS00435' saved to 'denoised_data\JS00435.mat'
# Modified data for record 'JS00436' saved to 'denoised_data\JS00436.mat'
# Modified data for record 'JS00437' saved to 'denoised_data\JS00437.mat'
# Modified data for record 'JS00438' saved to 'denoised_data\JS00438.mat'
# Modified data for record 'JS00439' saved to 'denoised_data\JS00439.mat'
# Modified data for record 'JS00440' saved to 'denoised_data\JS00440.mat'
# Modified data for record 'JS00441' saved to 'denoised_data\JS00441.mat'
# Modified data for record 'JS00442' saved to 'denoised_data\JS00442.mat'
# Modified data for record 'JS00444' saved to 'denoised_data\JS00444.mat'
# Modified data for record 'JS00445' saved to 'denoised_data\JS00445.mat'
# Modified data for record 'JS00446' saved to 'denoised_data\JS00446.mat'
# Modified data for record 'JS00447' saved to 'denoised_data\JS00447.mat'
# Modified data for record 'JS00448' saved to 'denoised_data\JS00448.mat'
# Modified data for record 'JS00449' saved to 'denoised_data\JS00449.mat'
# Modified data for record 'JS00450' saved to 'denoised_data\JS00450.mat'
# Modified data for record 'JS00451' saved to 'denoised_data\JS00451.mat'
# Modified data for record 'JS00452' saved to 'denoised_data\JS00452.mat'
# Modified data for record 'JS00453' saved to 'denoised_data\JS00453.mat'
# Modified data for record 'JS00454' saved to 'denoised_data\JS00454.mat'
# Modified data for record 'JS00455' saved to 'denoised_data\JS00455.mat'
# Modified data for record 'JS00456' saved to 'denoised_data\JS00456.mat'
# Modified data for record 'JS00457' saved to 'denoised_data\JS00457.mat'
# Modified data for record 'JS00458' saved to 'denoised_data\JS00458.mat'
# Modified data for record 'JS00459' saved to 'denoised_data\JS00459.mat'
# Modified data for record 'JS00461' saved to 'denoised_data\JS00461.mat'
# Modified data for record 'JS00462' saved to 'denoised_data\JS00462.mat'
# Modified data for record 'JS00463' saved to 'denoised_data\JS00463.mat'
# Modified data for record 'JS00464' saved to 'denoised_data\JS00464.mat'
# Modified data for record 'JS00465' saved to 'denoised_data\JS00465.mat'
# Modified data for record 'JS00466' saved to 'denoised_data\JS00466.mat'
# Modified data for record 'JS00467' saved to 'denoised_data\JS00467.mat'
# Modified data for record 'JS00468' saved to 'denoised_data\JS00468.mat'
# Modified data for record 'JS00469' saved to 'denoised_data\JS00469.mat'
# Modified data for record 'JS00470' saved to 'denoised_data\JS00470.mat'
# Modified data for record 'JS00471' saved to 'denoised_data\JS00471.mat'
# Modified data for record 'JS00472' saved to 'denoised_data\JS00472.mat'
# Modified data for record 'JS00473' saved to 'denoised_data\JS00473.mat'
# Modified data for record 'JS00474' saved to 'denoised_data\JS00474.mat'
# Modified data for record 'JS00475' saved to 'denoised_data\JS00475.mat'
# Modified data for record 'JS00476' saved to 'denoised_data\JS00476.mat'
# Modified data for record 'JS00477' saved to 'denoised_data\JS00477.mat'
# Modified data for record 'JS00478' saved to 'denoised_data\JS00478.mat'
# Modified data for record 'JS00479' saved to 'denoised_data\JS00479.mat'
# Modified data for record 'JS00480' saved to 'denoised_data\JS00480.mat'
# Modified data for record 'JS00481' saved to 'denoised_data\JS00481.mat'
# Modified data for record 'JS00482' saved to 'denoised_data\JS00482.mat'
# Modified data for record 'JS00483' saved to 'denoised_data\JS00483.mat'
# Modified data for record 'JS00484' saved to 'denoised_data\JS00484.mat'
# Modified data for record 'JS00485' saved to 'denoised_data\JS00485.mat'
# Modified data for record 'JS00486' saved to 'denoised_data\JS00486.mat'
# Modified data for record 'JS00487' saved to 'denoised_data\JS00487.mat'
# Modified data for record 'JS00488' saved to 'denoised_data\JS00488.mat'
# Modified data for record 'JS00490' saved to 'denoised_data\JS00490.mat'
# Modified data for record 'JS00491' saved to 'denoised_data\JS00491.mat'
# Modified data for record 'JS00492' saved to 'denoised_data\JS00492.mat'
# Modified data for record 'JS00493' saved to 'denoised_data\JS00493.mat'
# Modified data for record 'JS00494' saved to 'denoised_data\JS00494.mat'
# Modified data for record 'JS00495' saved to 'denoised_data\JS00495.mat'
# Modified data for record 'JS00496' saved to 'denoised_data\JS00496.mat'
# Modified data for record 'JS00497' saved to 'denoised_data\JS00497.mat'
# Modified data for record 'JS00498' saved to 'denoised_data\JS00498.mat'
# Modified data for record 'JS00499' saved to 'denoised_data\JS00499.mat'
# Modified data for record 'JS00500' saved to 'denoised_data\JS00500.mat'
# Modified data for record 'JS00501' saved to 'denoised_data\JS00501.mat'
# Modified data for record 'JS00502' saved to 'denoised_data\JS00502.mat'
# Modified data for record 'JS00503' saved to 'denoised_data\JS00503.mat'
# Modified data for record 'JS00504' saved to 'denoised_data\JS00504.mat'
# Modified data for record 'JS00506' saved to 'denoised_data\JS00506.mat'
# Modified data for record 'JS00507' saved to 'denoised_data\JS00507.mat'
# Modified data for record 'JS00508' saved to 'denoised_data\JS00508.mat'
# Modified data for record 'JS00509' saved to 'denoised_data\JS00509.mat'
# Modified data for record 'JS00510' saved to 'denoised_data\JS00510.mat'
# Modified data for record 'JS00511' saved to 'denoised_data\JS00511.mat'
# Modified data for record 'JS00512' saved to 'denoised_data\JS00512.mat'
# Modified data for record 'JS00513' saved to 'denoised_data\JS00513.mat'
# Modified data for record 'JS00514' saved to 'denoised_data\JS00514.mat'
# Modified data for record 'JS00515' saved to 'denoised_data\JS00515.mat'
# Modified data for record 'JS00516' saved to 'denoised_data\JS00516.mat'
# Modified data for record 'JS00517' saved to 'denoised_data\JS00517.mat'
# Modified data for record 'JS00518' saved to 'denoised_data\JS00518.mat'
# Modified data for record 'JS00519' saved to 'denoised_data\JS00519.mat'
# Modified data for record 'JS00520' saved to 'denoised_data\JS00520.mat'
# Modified data for record 'JS00521' saved to 'denoised_data\JS00521.mat'
# Modified data for record 'JS00522' saved to 'denoised_data\JS00522.mat'
# Modified data for record 'JS00523' saved to 'denoised_data\JS00523.mat'
# Modified data for record 'JS00524' saved to 'denoised_data\JS00524.mat'
# Modified data for record 'JS00525' saved to 'denoised_data\JS00525.mat'
# Modified data for record 'JS00526' saved to 'denoised_data\JS00526.mat'
# Modified data for record 'JS00527' saved to 'denoised_data\JS00527.mat'
# Modified data for record 'JS00528' saved to 'denoised_data\JS00528.mat'
# Modified data for record 'JS00529' saved to 'denoised_data\JS00529.mat'
# Modified data for record 'JS00530' saved to 'denoised_data\JS00530.mat'
# Modified data for record 'JS00531' saved to 'denoised_data\JS00531.mat'
# Modified data for record 'JS00532' saved to 'denoised_data\JS00532.mat'
# Modified data for record 'JS00533' saved to 'denoised_data\JS00533.mat'
# Modified data for record 'JS00534' saved to 'denoised_data\JS00534.mat'
# Modified data for record 'JS00535' saved to 'denoised_data\JS00535.mat'
# Modified data for record 'JS00536' saved to 'denoised_data\JS00536.mat'
# Modified data for record 'JS00537' saved to 'denoised_data\JS00537.mat'
# Modified data for record 'JS00538' saved to 'denoised_data\JS00538.mat'
# Modified data for record 'JS00540' saved to 'denoised_data\JS00540.mat'
# Modified data for record 'JS00541' saved to 'denoised_data\JS00541.mat'
# Modified data for record 'JS00543' saved to 'denoised_data\JS00543.mat'
# Modified data for record 'JS00544' saved to 'denoised_data\JS00544.mat'
# Modified data for record 'JS00545' saved to 'denoised_data\JS00545.mat'
# Modified data for record 'JS00546' saved to 'denoised_data\JS00546.mat'
# Modified data for record 'JS00547' saved to 'denoised_data\JS00547.mat'
# Modified data for record 'JS00548' saved to 'denoised_data\JS00548.mat'
# Modified data for record 'JS00549' saved to 'denoised_data\JS00549.mat'
# Modified data for record 'JS00550' saved to 'denoised_data\JS00550.mat'
# Modified data for record 'JS00552' saved to 'denoised_data\JS00552.mat'
# Modified data for record 'JS00553' saved to 'denoised_data\JS00553.mat'
# Modified data for record 'JS00554' saved to 'denoised_data\JS00554.mat'
# Modified data for record 'JS00556' saved to 'denoised_data\JS00556.mat'
# Modified data for record 'JS00557' saved to 'denoised_data\JS00557.mat'
# Modified data for record 'JS00558' saved to 'denoised_data\JS00558.mat'
# Modified data for record 'JS00559' saved to 'denoised_data\JS00559.mat'
# Modified data for record 'JS00560' saved to 'denoised_data\JS00560.mat'
# Modified data for record 'JS00561' saved to 'denoised_data\JS00561.mat'
# Modified data for record 'JS00562' saved to 'denoised_data\JS00562.mat'
# Modified data for record 'JS00563' saved to 'denoised_data\JS00563.mat'
# Modified data for record 'JS00564' saved to 'denoised_data\JS00564.mat'
# Modified data for record 'JS00565' saved to 'denoised_data\JS00565.mat'
# Modified data for record 'JS00566' saved to 'denoised_data\JS00566.mat'
# Modified data for record 'JS00567' saved to 'denoised_data\JS00567.mat'
# Modified data for record 'JS00568' saved to 'denoised_data\JS00568.mat'
# Modified data for record 'JS00569' saved to 'denoised_data\JS00569.mat'
# Modified data for record 'JS00570' saved to 'denoised_data\JS00570.mat'
# Modified data for record 'JS00571' saved to 'denoised_data\JS00571.mat'
# Modified data for record 'JS00572' saved to 'denoised_data\JS00572.mat'
# Modified data for record 'JS00573' saved to 'denoised_data\JS00573.mat'
# Modified data for record 'JS00574' saved to 'denoised_data\JS00574.mat'
# Modified data for record 'JS00575' saved to 'denoised_data\JS00575.mat'
# Modified data for record 'JS00576' saved to 'denoised_data\JS00576.mat'
# Modified data for record 'JS00577' saved to 'denoised_data\JS00577.mat'
# Modified data for record 'JS00578' saved to 'denoised_data\JS00578.mat'
# Modified data for record 'JS00579' saved to 'denoised_data\JS00579.mat'
# Modified data for record 'JS00580' saved to 'denoised_data\JS00580.mat'
# Modified data for record 'JS00581' saved to 'denoised_data\JS00581.mat'
# Modified data for record 'JS00582' saved to 'denoised_data\JS00582.mat'
# Modified data for record 'JS00583' saved to 'denoised_data\JS00583.mat'
# Modified data for record 'JS00585' saved to 'denoised_data\JS00585.mat'
# Modified data for record 'JS00586' saved to 'denoised_data\JS00586.mat'
# Modified data for record 'JS00587' saved to 'denoised_data\JS00587.mat'
# Modified data for record 'JS00588' saved to 'denoised_data\JS00588.mat'
# Modified data for record 'JS00589' saved to 'denoised_data\JS00589.mat'
# Modified data for record 'JS00590' saved to 'denoised_data\JS00590.mat'
# Modified data for record 'JS00591' saved to 'denoised_data\JS00591.mat'
# Modified data for record 'JS00592' saved to 'denoised_data\JS00592.mat'
# Modified data for record 'JS00594' saved to 'denoised_data\JS00594.mat'
# Modified data for record 'JS00595' saved to 'denoised_data\JS00595.mat'
# Modified data for record 'JS00596' saved to 'denoised_data\JS00596.mat'
# Modified data for record 'JS00597' saved to 'denoised_data\JS00597.mat'
# Modified data for record 'JS00598' saved to 'denoised_data\JS00598.mat'
# Modified data for record 'JS00599' saved to 'denoised_data\JS00599.mat'
# Modified data for record 'JS00600' saved to 'denoised_data\JS00600.mat'
# Modified data for record 'JS00601' saved to 'denoised_data\JS00601.mat'
# Modified data for record 'JS00602' saved to 'denoised_data\JS00602.mat'
# Modified data for record 'JS00603' saved to 'denoised_data\JS00603.mat'
# Modified data for record 'JS00605' saved to 'denoised_data\JS00605.mat'
# Modified data for record 'JS00606' saved to 'denoised_data\JS00606.mat'
# Modified data for record 'JS00607' saved to 'denoised_data\JS00607.mat'
# Modified data for record 'JS00608' saved to 'denoised_data\JS00608.mat'
# Modified data for record 'JS00609' saved to 'denoised_data\JS00609.mat'
# Modified data for record 'JS00610' saved to 'denoised_data\JS00610.mat'
# Modified data for record 'JS00611' saved to 'denoised_data\JS00611.mat'
# Modified data for record 'JS00612' saved to 'denoised_data\JS00612.mat'
# Modified data for record 'JS00613' saved to 'denoised_data\JS00613.mat'
# Modified data for record 'JS00614' saved to 'denoised_data\JS00614.mat'
# Modified data for record 'JS00615' saved to 'denoised_data\JS00615.mat'
# Modified data for record 'JS00616' saved to 'denoised_data\JS00616.mat'
# Modified data for record 'JS00617' saved to 'denoised_data\JS00617.mat'
# Modified data for record 'JS00618' saved to 'denoised_data\JS00618.mat'
# Modified data for record 'JS00619' saved to 'denoised_data\JS00619.mat'
# Modified data for record 'JS00620' saved to 'denoised_data\JS00620.mat'
# Modified data for record 'JS00621' saved to 'denoised_data\JS00621.mat'
# Modified data for record 'JS00623' saved to 'denoised_data\JS00623.mat'
# Modified data for record 'JS00624' saved to 'denoised_data\JS00624.mat'
# Modified data for record 'JS00625' saved to 'denoised_data\JS00625.mat'
# Modified data for record 'JS00626' saved to 'denoised_data\JS00626.mat'
# Modified data for record 'JS00627' saved to 'denoised_data\JS00627.mat'
# Modified data for record 'JS00628' saved to 'denoised_data\JS00628.mat'
# Modified data for record 'JS00629' saved to 'denoised_data\JS00629.mat'
# Modified data for record 'JS00630' saved to 'denoised_data\JS00630.mat'
# Modified data for record 'JS00631' saved to 'denoised_data\JS00631.mat'
# Modified data for record 'JS00633' saved to 'denoised_data\JS00633.mat'
# Modified data for record 'JS00634' saved to 'denoised_data\JS00634.mat'
# Modified data for record 'JS00635' saved to 'denoised_data\JS00635.mat'
# Modified data for record 'JS00636' saved to 'denoised_data\JS00636.mat'
# Modified data for record 'JS00637' saved to 'denoised_data\JS00637.mat'
# Modified data for record 'JS00638' saved to 'denoised_data\JS00638.mat'
# Modified data for record 'JS00639' saved to 'denoised_data\JS00639.mat'
# Modified data for record 'JS00640' saved to 'denoised_data\JS00640.mat'
# Modified data for record 'JS00641' saved to 'denoised_data\JS00641.mat'
# Modified data for record 'JS00642' saved to 'denoised_data\JS00642.mat'
# Modified data for record 'JS00643' saved to 'denoised_data\JS00643.mat'
# Modified data for record 'JS00644' saved to 'denoised_data\JS00644.mat'
# Modified data for record 'JS00645' saved to 'denoised_data\JS00645.mat'
# Modified data for record 'JS00646' saved to 'denoised_data\JS00646.mat'
# Modified data for record 'JS00647' saved to 'denoised_data\JS00647.mat'
# Modified data for record 'JS00648' saved to 'denoised_data\JS00648.mat'
# Modified data for record 'JS00649' saved to 'denoised_data\JS00649.mat'
# Modified data for record 'JS00651' saved to 'denoised_data\JS00651.mat'
# Modified data for record 'JS00652' saved to 'denoised_data\JS00652.mat'
# Modified data for record 'JS00653' saved to 'denoised_data\JS00653.mat'
# Modified data for record 'JS00654' saved to 'denoised_data\JS00654.mat'
# Modified data for record 'JS00655' saved to 'denoised_data\JS00655.mat'
# Modified data for record 'JS00656' saved to 'denoised_data\JS00656.mat'
# Modified data for record 'JS00657' saved to 'denoised_data\JS00657.mat'
# Modified data for record 'JS00659' saved to 'denoised_data\JS00659.mat'
# Modified data for record 'JS00660' saved to 'denoised_data\JS00660.mat'
# Modified data for record 'JS00661' saved to 'denoised_data\JS00661.mat'
# Modified data for record 'JS00662' saved to 'denoised_data\JS00662.mat'
# Modified data for record 'JS00663' saved to 'denoised_data\JS00663.mat'
# Modified data for record 'JS00664' saved to 'denoised_data\JS00664.mat'
# Modified data for record 'JS00665' saved to 'denoised_data\JS00665.mat'
# Modified data for record 'JS00666' saved to 'denoised_data\JS00666.mat'
# Modified data for record 'JS00667' saved to 'denoised_data\JS00667.mat'
# Modified data for record 'JS00668' saved to 'denoised_data\JS00668.mat'
# Modified data for record 'JS00669' saved to 'denoised_data\JS00669.mat'
# Modified data for record 'JS00670' saved to 'denoised_data\JS00670.mat'
# Modified data for record 'JS00671' saved to 'denoised_data\JS00671.mat'
# Modified data for record 'JS00672' saved to 'denoised_data\JS00672.mat'
# Modified data for record 'JS00673' saved to 'denoised_data\JS00673.mat'
# Modified data for record 'JS00674' saved to 'denoised_data\JS00674.mat'
# Modified data for record 'JS00675' saved to 'denoised_data\JS00675.mat'
# Modified data for record 'JS00677' saved to 'denoised_data\JS00677.mat'
# Modified data for record 'JS00679' saved to 'denoised_data\JS00679.mat'
# Modified data for record 'JS00680' saved to 'denoised_data\JS00680.mat'
# Modified data for record 'JS00681' saved to 'denoised_data\JS00681.mat'
# Modified data for record 'JS00682' saved to 'denoised_data\JS00682.mat'
# Modified data for record 'JS00683' saved to 'denoised_data\JS00683.mat'
# Modified data for record 'JS00684' saved to 'denoised_data\JS00684.mat'
# Modified data for record 'JS00685' saved to 'denoised_data\JS00685.mat'
# Modified data for record 'JS00686' saved to 'denoised_data\JS00686.mat'
# Modified data for record 'JS00687' saved to 'denoised_data\JS00687.mat'
# Modified data for record 'JS00688' saved to 'denoised_data\JS00688.mat'
# Modified data for record 'JS00689' saved to 'denoised_data\JS00689.mat'
# Modified data for record 'JS00690' saved to 'denoised_data\JS00690.mat'
# Modified data for record 'JS00691' saved to 'denoised_data\JS00691.mat'
# Modified data for record 'JS00692' saved to 'denoised_data\JS00692.mat'
# Modified data for record 'JS00693' saved to 'denoised_data\JS00693.mat'
# Modified data for record 'JS00694' saved to 'denoised_data\JS00694.mat'
# Modified data for record 'JS00695' saved to 'denoised_data\JS00695.mat'
# Modified data for record 'JS00696' saved to 'denoised_data\JS00696.mat'
# ...
# Modified data for record 'JS45330' saved to 'denoised_data\JS45330.mat'
# Modified data for record 'JS45331' saved to 'denoised_data\JS45331.mat'
# Modified data for record 'JS45332' saved to 'denoised_data\JS45332.mat'
# Modified data for record 'JS45333' saved to 'denoised_data\JS45333.mat'
# Modified data for record 'JS45334' saved to 'denoised_data\JS45334.mat'
# Modified data for record 'JS45335' saved to 'denoised_data\JS45335.mat'
# Modified data for record 'JS45336' saved to 'denoised_data\JS45336.mat'
# Modified data for record 'JS45337' saved to 'denoised_data\JS45337.mat'
# Modified data for record 'JS45338' saved to 'denoised_data\JS45338.mat'
# Modified data for record 'JS45339' saved to 'denoised_data\JS45339.mat'
# Modified data for record 'JS45340' saved to 'denoised_data\JS45340.mat'
# Modified data for record 'JS45341' saved to 'denoised_data\JS45341.mat'
# Modified data for record 'JS45342' saved to 'denoised_data\JS45342.mat'
# Modified data for record 'JS45343' saved to 'denoised_data\JS45343.mat'
# Modified data for record 'JS45344' saved to 'denoised_data\JS45344.mat'
# Modified data for record 'JS45345' saved to 'denoised_data\JS45345.mat'
# Modified data for record 'JS45346' saved to 'denoised_data\JS45346.mat'
# Modified data for record 'JS45347' saved to 'denoised_data\JS45347.mat'
# Modified data for record 'JS45348' saved to 'denoised_data\JS45348.mat'
# Modified data for record 'JS45349' saved to 'denoised_data\JS45349.mat'
# Modified data for record 'JS45350' saved to 'denoised_data\JS45350.mat'
# Modified data for record 'JS45351' saved to 'denoised_data\JS45351.mat'
# Modified data for record 'JS45352' saved to 'denoised_data\JS45352.mat'
# Modified data for record 'JS45353' saved to 'denoised_data\JS45353.mat'
# Modified data for record 'JS45354' saved to 'denoised_data\JS45354.mat'
# Modified data for record 'JS45355' saved to 'denoised_data\JS45355.mat'
# Modified data for record 'JS45356' saved to 'denoised_data\JS45356.mat'
# Modified data for record 'JS45357' saved to 'denoised_data\JS45357.mat'
# Modified data for record 'JS45358' saved to 'denoised_data\JS45358.mat'
# Modified data for record 'JS45359' saved to 'denoised_data\JS45359.mat'
# Modified data for record 'JS45360' saved to 'denoised_data\JS45360.mat'
# Modified data for record 'JS45361' saved to 'denoised_data\JS45361.mat'
# Modified data for record 'JS45362' saved to 'denoised_data\JS45362.mat'
# Modified data for record 'JS45363' saved to 'denoised_data\JS45363.mat'
# Modified data for record 'JS45364' saved to 'denoised_data\JS45364.mat'
# Modified data for record 'JS45365' saved to 'denoised_data\JS45365.mat'
# Modified data for record 'JS45366' saved to 'denoised_data\JS45366.mat'
# Modified data for record 'JS45367' saved to 'denoised_data\JS45367.mat'
# Modified data for record 'JS45368' saved to 'denoised_data\JS45368.mat'
# Modified data for record 'JS45369' saved to 'denoised_data\JS45369.mat'
# Modified data for record 'JS45370' saved to 'denoised_data\JS45370.mat'
# Modified data for record 'JS45371' saved to 'denoised_data\JS45371.mat'
# Modified data for record 'JS45372' saved to 'denoised_data\JS45372.mat'
# Modified data for record 'JS45373' saved to 'denoised_data\JS45373.mat'
# Modified data for record 'JS45374' saved to 'denoised_data\JS45374.mat'
# Modified data for record 'JS45375' saved to 'denoised_data\JS45375.mat'
# Modified data for record 'JS45376' saved to 'denoised_data\JS45376.mat'
# Modified data for record 'JS45377' saved to 'denoised_data\JS45377.mat'
# Modified data for record 'JS45378' saved to 'denoised_data\JS45378.mat'
# Modified data for record 'JS45379' saved to 'denoised_data\JS45379.mat'
# Modified data for record 'JS45380' saved to 'denoised_data\JS45380.mat'
# Modified data for record 'JS45381' saved to 'denoised_data\JS45381.mat'
# Modified data for record 'JS45382' saved to 'denoised_data\JS45382.mat'
# Modified data for record 'JS45383' saved to 'denoised_data\JS45383.mat'
# Modified data for record 'JS45384' saved to 'denoised_data\JS45384.mat'
# Modified data for record 'JS45385' saved to 'denoised_data\JS45385.mat'
# Modified data for record 'JS45386' saved to 'denoised_data\JS45386.mat'
# Modified data for record 'JS45387' saved to 'denoised_data\JS45387.mat'
# Modified data for record 'JS45388' saved to 'denoised_data\JS45388.mat'
# Modified data for record 'JS45389' saved to 'denoised_data\JS45389.mat'
# Modified data for record 'JS45390' saved to 'denoised_data\JS45390.mat'
# Modified data for record 'JS45391' saved to 'denoised_data\JS45391.mat'
# Modified data for record 'JS45392' saved to 'denoised_data\JS45392.mat'
# Modified data for record 'JS45393' saved to 'denoised_data\JS45393.mat'
# Modified data for record 'JS45394' saved to 'denoised_data\JS45394.mat'
# Modified data for record 'JS45395' saved to 'denoised_data\JS45395.mat'
# Modified data for record 'JS45396' saved to 'denoised_data\JS45396.mat'
# Modified data for record 'JS45397' saved to 'denoised_data\JS45397.mat'
# Modified data for record 'JS45398' saved to 'denoised_data\JS45398.mat'
# Modified data for record 'JS45399' saved to 'denoised_data\JS45399.mat'
# Modified data for record 'JS45400' saved to 'denoised_data\JS45400.mat'
# Modified data for record 'JS45401' saved to 'denoised_data\JS45401.mat'
# Modified data for record 'JS45402' saved to 'denoised_data\JS45402.mat'
# Modified data for record 'JS45403' saved to 'denoised_data\JS45403.mat'
# Modified data for record 'JS45404' saved to 'denoised_data\JS45404.mat'
# Modified data for record 'JS45405' saved to 'denoised_data\JS45405.mat'
# Modified data for record 'JS45406' saved to 'denoised_data\JS45406.mat'
# Modified data for record 'JS45407' saved to 'denoised_data\JS45407.mat'
# Modified data for record 'JS45408' saved to 'denoised_data\JS45408.mat'
# Modified data for record 'JS45409' saved to 'denoised_data\JS45409.mat'
# Modified data for record 'JS45410' saved to 'denoised_data\JS45410.mat'
# Modified data for record 'JS45411' saved to 'denoised_data\JS45411.mat'
# Modified data for record 'JS45412' saved to 'denoised_data\JS45412.mat'
# Modified data for record 'JS45413' saved to 'denoised_data\JS45413.mat'
# Modified data for record 'JS45414' saved to 'denoised_data\JS45414.mat'
# Modified data for record 'JS45415' saved to 'denoised_data\JS45415.mat'
# Modified data for record 'JS45416' saved to 'denoised_data\JS45416.mat'
# Modified data for record 'JS45417' saved to 'denoised_data\JS45417.mat'
# Modified data for record 'JS45418' saved to 'denoised_data\JS45418.mat'
# Modified data for record 'JS45419' saved to 'denoised_data\JS45419.mat'
# Modified data for record 'JS45420' saved to 'denoised_data\JS45420.mat'
# Modified data for record 'JS45421' saved to 'denoised_data\JS45421.mat'
# Modified data for record 'JS45422' saved to 'denoised_data\JS45422.mat'
# Modified data for record 'JS45423' saved to 'denoised_data\JS45423.mat'
# Modified data for record 'JS45424' saved to 'denoised_data\JS45424.mat'
# Modified data for record 'JS45425' saved to 'denoised_data\JS45425.mat'
# Modified data for record 'JS45426' saved to 'denoised_data\JS45426.mat'
# Modified data for record 'JS45427' saved to 'denoised_data\JS45427.mat'
# Modified data for record 'JS45428' saved to 'denoised_data\JS45428.mat'
# Modified data for record 'JS45429' saved to 'denoised_data\JS45429.mat'
# Modified data for record 'JS45430' saved to 'denoised_data\JS45430.mat'
# Modified data for record 'JS45431' saved to 'denoised_data\JS45431.mat'
# Modified data for record 'JS45432' saved to 'denoised_data\JS45432.mat'
# Modified data for record 'JS45433' saved to 'denoised_data\JS45433.mat'
# Modified data for record 'JS45434' saved to 'denoised_data\JS45434.mat'
# Modified data for record 'JS45435' saved to 'denoised_data\JS45435.mat'
# Modified data for record 'JS45436' saved to 'denoised_data\JS45436.mat'
# Modified data for record 'JS45437' saved to 'denoised_data\JS45437.mat'
# Modified data for record 'JS45438' saved to 'denoised_data\JS45438.mat'
# Modified data for record 'JS45439' saved to 'denoised_data\JS45439.mat'
# Modified data for record 'JS45440' saved to 'denoised_data\JS45440.mat'
# Modified data for record 'JS45441' saved to 'denoised_data\JS45441.mat'
# Modified data for record 'JS45442' saved to 'denoised_data\JS45442.mat'
# Modified data for record 'JS45443' saved to 'denoised_data\JS45443.mat'
# Modified data for record 'JS45444' saved to 'denoised_data\JS45444.mat'
# Modified data for record 'JS45445' saved to 'denoised_data\JS45445.mat'
# Modified data for record 'JS45446' saved to 'denoised_data\JS45446.mat'
# Modified data for record 'JS45447' saved to 'denoised_data\JS45447.mat'
# Modified data for record 'JS45448' saved to 'denoised_data\JS45448.mat'
# Modified data for record 'JS45449' saved to 'denoised_data\JS45449.mat'
# Modified data for record 'JS45450' saved to 'denoised_data\JS45450.mat'
# Modified data for record 'JS45451' saved to 'denoised_data\JS45451.mat'
# Modified data for record 'JS45452' saved to 'denoised_data\JS45452.mat'
# Modified data for record 'JS45453' saved to 'denoised_data\JS45453.mat'
# Modified data for record 'JS45454' saved to 'denoised_data\JS45454.mat'
# Modified data for record 'JS45455' saved to 'denoised_data\JS45455.mat'
# Modified data for record 'JS45456' saved to 'denoised_data\JS45456.mat'
# Modified data for record 'JS45457' saved to 'denoised_data\JS45457.mat'
# Modified data for record 'JS45458' saved to 'denoised_data\JS45458.mat'
# Modified data for record 'JS45459' saved to 'denoised_data\JS45459.mat'
# Modified data for record 'JS45460' saved to 'denoised_data\JS45460.mat'
# Modified data for record 'JS45461' saved to 'denoised_data\JS45461.mat'
# Modified data for record 'JS45462' saved to 'denoised_data\JS45462.mat'
# Modified data for record 'JS45463' saved to 'denoised_data\JS45463.mat'
# Modified data for record 'JS45464' saved to 'denoised_data\JS45464.mat'
# Modified data for record 'JS45465' saved to 'denoised_data\JS45465.mat'
# Modified data for record 'JS45466' saved to 'denoised_data\JS45466.mat'
# Modified data for record 'JS45467' saved to 'denoised_data\JS45467.mat'
# Modified data for record 'JS45468' saved to 'denoised_data\JS45468.mat'
# Modified data for record 'JS45469' saved to 'denoised_data\JS45469.mat'
# Modified data for record 'JS45470' saved to 'denoised_data\JS45470.mat'
# Modified data for record 'JS45471' saved to 'denoised_data\JS45471.mat'
# Modified data for record 'JS45472' saved to 'denoised_data\JS45472.mat'
# Modified data for record 'JS45473' saved to 'denoised_data\JS45473.mat'
# Modified data for record 'JS45474' saved to 'denoised_data\JS45474.mat'
# Modified data for record 'JS45475' saved to 'denoised_data\JS45475.mat'
# Modified data for record 'JS45476' saved to 'denoised_data\JS45476.mat'
# Modified data for record 'JS45477' saved to 'denoised_data\JS45477.mat'
# Modified data for record 'JS45478' saved to 'denoised_data\JS45478.mat'
# Modified data for record 'JS45479' saved to 'denoised_data\JS45479.mat'
# Modified data for record 'JS45480' saved to 'denoised_data\JS45480.mat'
# Modified data for record 'JS45481' saved to 'denoised_data\JS45481.mat'
# Modified data for record 'JS45482' saved to 'denoised_data\JS45482.mat'
# Modified data for record 'JS45483' saved to 'denoised_data\JS45483.mat'
# Modified data for record 'JS45484' saved to 'denoised_data\JS45484.mat'
# Modified data for record 'JS45485' saved to 'denoised_data\JS45485.mat'
# Modified data for record 'JS45486' saved to 'denoised_data\JS45486.mat'
# Modified data for record 'JS45487' saved to 'denoised_data\JS45487.mat'
# Modified data for record 'JS45488' saved to 'denoised_data\JS45488.mat'
# Modified data for record 'JS45489' saved to 'denoised_data\JS45489.mat'
# Modified data for record 'JS45490' saved to 'denoised_data\JS45490.mat'
# Modified data for record 'JS45491' saved to 'denoised_data\JS45491.mat'
# Modified data for record 'JS45492' saved to 'denoised_data\JS45492.mat'
# Modified data for record 'JS45493' saved to 'denoised_data\JS45493.mat'
# Modified data for record 'JS45494' saved to 'denoised_data\JS45494.mat'
# Modified data for record 'JS45495' saved to 'denoised_data\JS45495.mat'
# Modified data for record 'JS45496' saved to 'denoised_data\JS45496.mat'
# Modified data for record 'JS45497' saved to 'denoised_data\JS45497.mat'
# Modified data for record 'JS45498' saved to 'denoised_data\JS45498.mat'
# Modified data for record 'JS45499' saved to 'denoised_data\JS45499.mat'
# Modified data for record 'JS45500' saved to 'denoised_data\JS45500.mat'
# Modified data for record 'JS45501' saved to 'denoised_data\JS45501.mat'
# Modified data for record 'JS45502' saved to 'denoised_data\JS45502.mat'
# Modified data for record 'JS45503' saved to 'denoised_data\JS45503.mat'
# Modified data for record 'JS45504' saved to 'denoised_data\JS45504.mat'
# Modified data for record 'JS45505' saved to 'denoised_data\JS45505.mat'
# Modified data for record 'JS45506' saved to 'denoised_data\JS45506.mat'
# Modified data for record 'JS45507' saved to 'denoised_data\JS45507.mat'
# Modified data for record 'JS45508' saved to 'denoised_data\JS45508.mat'
# Modified data for record 'JS45509' saved to 'denoised_data\JS45509.mat'
# Modified data for record 'JS45510' saved to 'denoised_data\JS45510.mat'
# Modified data for record 'JS45511' saved to 'denoised_data\JS45511.mat'
# Modified data for record 'JS45512' saved to 'denoised_data\JS45512.mat'
# Modified data for record 'JS45513' saved to 'denoised_data\JS45513.mat'
# Modified data for record 'JS45514' saved to 'denoised_data\JS45514.mat'
# Modified data for record 'JS45515' saved to 'denoised_data\JS45515.mat'
# Modified data for record 'JS45516' saved to 'denoised_data\JS45516.mat'
# Modified data for record 'JS45517' saved to 'denoised_data\JS45517.mat'
# Modified data for record 'JS45518' saved to 'denoised_data\JS45518.mat'
# Modified data for record 'JS45519' saved to 'denoised_data\JS45519.mat'
# Modified data for record 'JS45520' saved to 'denoised_data\JS45520.mat'
# Modified data for record 'JS45521' saved to 'denoised_data\JS45521.mat'
# Modified data for record 'JS45522' saved to 'denoised_data\JS45522.mat'
# Modified data for record 'JS45523' saved to 'denoised_data\JS45523.mat'
# Modified data for record 'JS45524' saved to 'denoised_data\JS45524.mat'
# Modified data for record 'JS45525' saved to 'denoised_data\JS45525.mat'
# Modified data for record 'JS45526' saved to 'denoised_data\JS45526.mat'
# Modified data for record 'JS45527' saved to 'denoised_data\JS45527.mat'
# Modified data for record 'JS45528' saved to 'denoised_data\JS45528.mat'
# Modified data for record 'JS45529' saved to 'denoised_data\JS45529.mat'
# Modified data for record 'JS45530' saved to 'denoised_data\JS45530.mat'
# Modified data for record 'JS45531' saved to 'denoised_data\JS45531.mat'
# Modified data for record 'JS45532' saved to 'denoised_data\JS45532.mat'
# Modified data for record 'JS45533' saved to 'denoised_data\JS45533.mat'
# Modified data for record 'JS45534' saved to 'denoised_data\JS45534.mat'
# Modified data for record 'JS45535' saved to 'denoised_data\JS45535.mat'
# Modified data for record 'JS45536' saved to 'denoised_data\JS45536.mat'
# Modified data for record 'JS45537' saved to 'denoised_data\JS45537.mat'
# Modified data for record 'JS45538' saved to 'denoised_data\JS45538.mat'
# Modified data for record 'JS45539' saved to 'denoised_data\JS45539.mat'
# Modified data for record 'JS45540' saved to 'denoised_data\JS45540.mat'
# Modified data for record 'JS45541' saved to 'denoised_data\JS45541.mat'
# Modified data for record 'JS45542' saved to 'denoised_data\JS45542.mat'
# Modified data for record 'JS45543' saved to 'denoised_data\JS45543.mat'
# Modified data for record 'JS45544' saved to 'denoised_data\JS45544.mat'
# Modified data for record 'JS45545' saved to 'denoised_data\JS45545.mat'
# Modified data for record 'JS45546' saved to 'denoised_data\JS45546.mat'
# Modified data for record 'JS45547' saved to 'denoised_data\JS45547.mat'
# Modified data for record 'JS45548' saved to 'denoised_data\JS45548.mat'
# Modified data for record 'JS45549' saved to 'denoised_data\JS45549.mat'
# Modified data for record 'JS45550' saved to 'denoised_data\JS45550.mat'
# Modified data for record 'JS45551' saved to 'denoised_data\JS45551.mat'

# %%
import os
import shutil

def copy_hea_files(data_dir, destination_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Recursively search for .hea files in subdirectories of data_dir
    for root, dirs, files in os.walk(data_dir):
        for filename in files:
            if filename.endswith('.hea'):
                file_path = os.path.join(root, filename)
                # Copy the .hea file to the destination directory
                shutil.copy(file_path, destination_dir)

# Provide the directory where the data is located and the destination directory
data_dir = "data\WFDBRecords"
destination_dir = "denoised_data"

copy_hea_files(data_dir, destination_dir)
